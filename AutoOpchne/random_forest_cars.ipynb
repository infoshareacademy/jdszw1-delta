# %% [markdown]
# Firma AAAAutoSprzedam jest platformą umożliwiającą publikowanie ogłoszeń sprzedaży
# samochodów. Oprócz bardzo taniego ogłoszenia typu Basic oferuje swoim klientom –
# ogłoszeniodawcom – również płatne promowane ogłoszenia typu Premium i Plus. Na liście
# ogłoszeń w pierwszej kolejności pojawiają się ofery Premium, następnie Plus a na końcu pozostałe
# ogłoszenia.  Klienci są informowani, że wykupienie płatego ogłoszenia zwiększy jego skuteczność.
# W celu zwiększenia efektywności sprzedaży promowanych, dział komunikacji z klientem
# potrzebuje wiedzy o tym, jak poszczególne produkty wpływają na sukces ogłoszeniodawcy.
# Pomoże to doprecyzować przekaz o skuteczność płatnego ogłoszenia Premium lub Plus.
# Zespół analityczny proszony jest o przygotowanie 15 minutowej prezentacji, odpowiadającej na
# pytania:<br>
# • Jaki jest wpływ droższych produktów na skuteczność ogłoszenia?<br>
# • Czy w danych są wzorce, które uznalibyście za ciekawe lub niespodziewane?<br>
# • Jaki jest wpływ dostępnych zmiennych na skuteczność ogłoszenia?<br>
# • Jakie dodatkowe dane mogłyby być wykorzystane w analizie?<br>

# %% [markdown]
# views per day

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('AAAutoSprzedam_data.csv', sep=';')

# %%
data.isnull().sum()
# Out:
# article_id                  0
# product_tier                0
# make_name                   0
# price                       0
# first_zip_digit             0
# first_registration_year     0
# created_date                0
# deleted_date                0
# search_views               10
# detail_views               10
# stock_days                  0
# ctr                        24
# dtype: int64

# %%
data.created_date = pd.to_datetime(data.created_date)
data.deleted_date = pd.to_datetime(data.deleted_date)

# %%
stock_days2 = data.deleted_date - data.created_date

# %%
data['stock_days2'] = stock_days2

# %%
data.stock_days2 = data.stock_days2/np.timedelta64(1, 'D')
data.stock_days2 = data.stock_days2 + 1

# %%
data.stock_days2.min()
# Out:
# 1.0

# %%
data[data.stock_days2 == 0]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr, stock_days2]
# Index: []

# %%
data.drop('stock_days',axis=1,inplace=True)

# %%
data['ctr2'] = data.detail_views/data.search_views

# %%
data.drop('ctr',axis=1, inplace=True)

# %%
data.article_id.value_counts().head(20)
# Out:
# 359772384    2
# 360768628    2
# 360768627    2
# 364638423    2
# 350214315    2
# 360768625    2
# 360768632    2
# 360768624    2
# 354755824    2
# 350214314    2
# 354755822    2
# 360472733    2
# 357528924    2
# 360793587    2
# 358519054    2
# 354755829    2
# 359754168    1
# 349571668    1
# 360448597    1
# 350173618    1
# Name: article_id, dtype: int64

# %%
data = data.sort_values(by='article_id')

# %%
data = data.drop_duplicates(subset='article_id', keep=False)

# %%
data.sort_values('article_id',ascending=True)
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 38868   347232386        Basic         Nissan   6850                7
# 29915   347232409        Basic        Peugeot    850                5
# 45555   347232416        Basic  Mercedes-Benz  16950                7
# 77759   347232417        Basic          Skoda   2995                6
# 72821   347232422        Basic         Toyota   4300                4
# 3076    347232425        Basic           Opel   1850                4
# 48396   347246626        Basic         Toyota   6450                1
# 51363   347246657        Basic         Toyota   9450                3
# 71680   347246658        Basic         Toyota   9250                3
# 13874   347246660        Basic            BMW  24890                4
# 6915    347246667        Basic     Volkswagen  25250                6
# 45915   347246673        Basic          Mazda  24745                7
# ...

# %%
data['dv_perD'] = data.detail_views/data.stock_days2

# %%
data['sv_perD'] = data.search_views/data.stock_days2

# %%
data.sort_values(['sv_perD','dv_perD'],ascending=False)
# Out:
#        article_id product_tier       make_name  price  first_zip_digit  \
# 64208   360493469        Basic           Volvo    100                1
# 5179    363933708      Premium            Audi   4500                2
# 44791   363933706      Premium            Audi   4500                2
# 38966   363933707      Premium            Audi   4500                2
# 74838   359753805        Basic         Renault    199                7
# 49762   357876594        Basic         Citroen     99                7
# 72007   348760265      Premium         Peugeot    649                3
# 13945   358532508      Premium            Ford    575                3
# 10721   347277802      Premium            Fiat    499                5
# 51285   354421135      Premium            Audi   1245                6
# 34715   353090153      Premium         Peugeot    750                4
# 59428   360100662         Plus            Opel    300                5
# ...

# %%
data.first_registration_year.replace(2106,2006,True)

# %%
data.first_registration_year.replace(2020,2002,True)

# %%
data['old'] = 2019 - data.first_registration_year

# %%
data.sort_values('first_registration_year',0,False)
# Out:
#        article_id product_tier      make_name   price  first_zip_digit  \
# 7047    363572119        Basic     Land Rover  178888                5
# 78161   355477561        Basic          Skoda   34950                7
# 41755   355477564        Basic          Skoda   21995                7
# 46681   355477563        Basic          Skoda   20695                7
# 22265   360811305        Basic     Volkswagen   35745                1
# 33306   359233680        Basic         Nissan   26945                3
# 57720   355477562        Basic          Skoda   21650                7
# 35693   363592564        Basic          Volvo   55130                2
# 36997   360811304        Basic     Volkswagen   37250                1
# 41917   363615551        Basic     Volkswagen   28345                4
# 35599   363943781        Basic           Audi   32600                8
# 12944   363609848        Basic           Ford   74950                7
# ...

# %%
data.groupby(by='product_tier').mean()
# Out:
#                 article_id         price  first_zip_digit  \
# product_tier
# Basic         3.574594e+08  15100.425396         4.644016
# Plus          3.590835e+08  12828.761821         4.716287
# Premium       3.579793e+08  14648.924341         4.191526
#
#               first_registration_year  search_views  detail_views  \
# product_tier
# Basic                     2011.122658   1909.310405     82.542171
# Plus                      2009.577933   6754.464098    249.821366
# Premium                   2010.368785  13419.518374    399.963251
#
#               stock_days2      ctr2    dv_perD     sv_perD       old
# product_tier
# Basic           37.034361  0.047283   2.790178   58.362783  7.877342
# Plus            39.831874  0.040950   7.527167  197.687253  9.422067
# Premium         34.284911  0.035783  13.323658  436.896388  8.631215

# %%
data = data.dropna()

# %%
data = data.drop('article_id', axis = 1)

# %%
data.groupby('make_name').count()
# Out:
#                 product_tier  price  first_zip_digit  first_registration_year  \
# make_name
# AC                         1      1                1                        1
# Abarth                    21     21               21                       21
# Aixam                     24     24               24                       24
# Alfa Romeo               532    532              532                      532
# Alpina                     7      7                7                        7
# Alpine                     3      3                3                        3
# Amphicar                   1      1                1                        1
# Aston Martin              22     22               22                       22
# Audi                    3311   3311             3311                     3311
# Austin                    11     11               11                       11
# BMW                     4551   4551             4551                     4551
# ...

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data.head()
# Out:
#       product_tier      make_name  price  first_zip_digit  \
# 38868        Basic         Nissan   6850                7
# 29915        Basic        Peugeot    850                5
# 45555        Basic  Mercedes-Benz  16950                7
# 77759        Basic          Skoda   2995                6
# 72821        Basic         Toyota   4300                4
#
#        first_registration_year created_date deleted_date  search_views  \
# 38868                     2005   2018-07-04   2018-07-13         297.0
# 29915                     2004   2018-07-04   2018-08-14        3920.0
# 45555                     2013   2018-07-04   2018-09-15        1564.0
# 77759                     2010   2018-07-04   2018-07-16        2372.0
# 72821                     2008   2018-07-04   2018-10-01        3215.0
#
#        detail_views  stock_days2      ctr2    dv_perD     sv_perD  old
# 38868          22.0         10.0  0.074074   2.200000   29.700000   14
# ...

# %%
data.columns
# Out:
# Index(['product_tier', 'make_name', 'price', 'first_zip_digit',
#        'first_registration_year', 'created_date', 'deleted_date',
#        'search_views', 'detail_views', 'stock_days2', 'ctr2', 'dv_perD',
#        'sv_perD', 'old'],
#       dtype='object')

# %%
iksy = data.drop(['search_views', 'detail_views', 'created_date', 'deleted_date'] ,axis='columns')

# %%
iksy['product_tier_n'] = le.fit_transform(iksy['product_tier'])
iksy['make_name_n'] = le.fit_transform(iksy['make_name'])

# %%
iksy.columns
# Out:
# Index(['product_tier', 'make_name', 'price', 'first_zip_digit',
#        'first_registration_year', 'stock_days2', 'ctr2', 'dv_perD', 'sv_perD',
#        'old', 'product_tier_n', 'make_name_n'],
#       dtype='object')

# %%
X = iksy.drop(['first_registration_year','product_tier', 'make_name', 'stock_days2', 'ctr2', 'dv_perD', 'sv_perD'] ,axis='columns')
ys = data.search_views

# %%
ys
# Out:
# 38868      297.0
# 29915     3920.0
# 45555     1564.0
# 77759     2372.0
# 72821     3215.0
# 3076       231.0
# 48396      236.0
# 51363       74.0
# 71680      204.0
# 13874     7456.0
# 6915       635.0
# 45915      235.0
# 40192      474.0
# 77984     2084.0
# 16815       22.0
# 13449      470.0
# 56489     1578.0
# 25906      148.0
# 6646       463.0
# 57451       85.0
# 34465       26.0
# 39510      200.0
# 57453      192.0
# 27731      105.0
# 15940      277.0
# 34466      288.0
# 5646      1143.0
# 44025      232.0
# 24395      692.0
# 69661     4406.0
#           ...
# 29548     2300.0
# 45433      334.0
# 31958      142.0
# 37023      682.0
# 56551    31332.0
# 47927     4814.0
# 16750     6626.0
# 72160     1037.0
# 14865     1449.0
# 65908     1541.0
# 53980     6588.0
# 74757    46908.0
# 1306     17800.0
# 14881     2800.0
# 69387     3350.0
# 50331      829.0
# 11596     3936.0
# 67579     4039.0
# 9183      1526.0
# 65756     2343.0
# 5918      3116.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X
# Out:
#        price  first_zip_digit  old  product_tier_n  make_name_n
# 38868   6850                7   14               0           64
# 29915    850                5   15               0           69
# 45555  16950                7    6               0           60
# 77759   2995                6    9               0           78
# 72821   4300                4   11               0           85
# 3076    1850                4   16               0           67
# 48396   6450                1   10               0           85
# 51363   9450                3    3               0           85
# 71680   9250                3    3               0           85
# 13874  24890                4    5               0           10
# 6915   25250                6    4               0           88
# 45915  24745                7    5               0           58
# 40192  15900                5    9               0           88
# 77984  42900                5    4               0            8
# ...

# %%
regressor = RandomForestRegressor(n_estimators=200, random_state=0)
regressor.fit(X_train, ys_train)
ys_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
import sklearn.metrics
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ys_test, ys_pred))
print('Mean Squared Error:', metrics.mean_squared_error(ys_test, ys_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ys_test, ys_pred)))
# Out:
# Mean Absolute Error: 2084.0776161700455
# Mean Squared Error: 26631094.730673265
# Root Mean Squared Error: 5160.532407675904

# %%
regressor.score(X_test, ys_test)
# Out:
# 0.07827551023121704

# %%
pd.DataFrame({'Actual':ys_test, 'Predicted':ys_pred})
# Out:
#         Actual    Predicted
# 31073    317.0   876.717140
# 76701   7619.0  9471.475000
# 68761    941.0   722.652000
# 69685     43.0  1432.200000
# 64154    191.0  1880.748333
# 51744   1811.0  1201.756839
# 51493    427.0  1295.391667
# 40108   2090.0  2037.075000
# 66078    914.0  2836.425833
# 8798     723.0  1259.574690
# 42690    280.0   896.550000
# 4189    1807.0   323.739167
# 55      1401.0  1179.968214
# 69824   1171.0   173.991332
# 16738    325.0   947.275238
# 60124    420.0  2156.938333
# 58472    953.0  1224.395000
# 22562   1830.0  1557.910000
# 27627    941.0   901.273095
# 23881   3280.0  1586.691000
# 36258   1647.0  2390.187500
# 56648   3322.0  2408.943167
# 74503   6043.0  3780.955500
# 38772    174.0  2155.333250
# 28122   3121.0  2651.450476
# 31164    259.0  1016.231250
# 23482   1918.0  1540.572000
# 19407   1037.0  1591.482000
# 64625    156.0  1448.337917
# 38790    369.0  5082.000000
# ...        ...          ...
# 69911    184.0   870.925000
# ...

# %%
X2 = iksy.drop(['first_registration_year','product_tier', 'make_name', 'stock_days2', 'ctr2', 'dv_perD', 'sv_perD'] ,axis='columns')
yd = data.detail_views

# %%
X2_train, X2_test, yd_train, yd_test = train_test_split(X2, yd, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X2_train = sc.fit_transform(X2_train)
X2_test = sc.transform(X2_test)
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
regressor = RandomForestRegressor(n_estimators=50, random_state=0)
regressor.fit(X2_train, yd_train)
yd_pred = regressor.predict(X2_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(yd_test, yd_pred))
print('Mean Squared Error:', metrics.mean_squared_error(yd_test, yd_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yd_test, yd_pred)))
# Out:
# Mean Absolute Error: 91.6982980931201
# Mean Squared Error: 53064.075185038964
# Root Mean Squared Error: 230.3564090383399

# %%
regressor.score(X2_test, yd_test)
# Out:
# -0.0073317135894535035

# %% [markdown]
# # Z wyciętymi danymi

# %%
data1 = pd.read_csv("cut_data.csv")

# %%
data1['product_tier_n'] = le.fit_transform(data1['product_tier'])
data1['make_name_n'] = le.fit_transform(data1['make_name'])

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'product_tier', 'make_name', 'price', 'first_zip_digit',
#        'first_registration_year', 'created_date', 'deleted_date',
#        'search_views', 'detail_views', 'ctr', 'stock_days2', 'age',
#        'product_tier_n', 'make_name_n'],
#       dtype='object')

# %%
iksy2 = data1.drop(['Unnamed: 0', 'product_tier', 'make_name', 'first_registration_year', 'created_date', 'deleted_date',
       'search_views', 'detail_views', 'ctr',], axis = 'columns')

# %%
X3 = iksy2
ys2 = data1.search_views

# %%
X3_train, X3_test, ys2_train, ys2_test = train_test_split(X3, ys2, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X3_train = sc.fit_transform(X3_train)
X3_test = sc.transform(X3_test)
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
regressor = RandomForestRegressor(n_estimators=150, random_state=0)
regressor.fit(X3_train, ys2_train)
ys2_pred = regressor.predict(X3_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ys2_test, ys2_pred))
print('Mean Squared Error:', metrics.mean_squared_error(ys2_test, ys2_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ys2_test, ys2_pred)))
# Out:
# Mean Absolute Error: 1384.9514098480172
# Mean Squared Error: 15240229.626598768
# Root Mean Squared Error: 3903.873669395408

# %%
regressor.score(X3_test, ys2_test)
# Out:
# 0.49735326709920646

# %% [markdown]
# # Z bardziej wyciętymi danymi (data_mn>=150)

# %%
cut_data1 = data[data['make_name'].isin(['Alfa Romeo', 'Audi', 'BMW', 'Chevrolet', 'Citroen', 'Dacia',
       'Daihatsu', 'Fiat', 'Ford', 'Honda', 'Hyundai', 'Iveco', 'Jaguar',
       'Jeep', 'Kia', 'Land Rover', 'Lexus', 'MINI', 'Mazda',
       'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Opel', 'Peugeot',
       'Porsche', 'Renault', 'SEAT', 'Saab', 'Skoda', 'Subaru', 'Suzuki',
       'Toyota', 'Volkswagen', 'Volvo', 'smart'])]

# %%
cut_data1['product_tier_n'] = le.fit_transform(cut_data1['product_tier'])
cut_data1['make_name_n'] = le.fit_transform(cut_data1['make_name'])
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cut_data1.columns
# Out:
# Index(['product_tier', 'make_name', 'price', 'first_zip_digit',
#        'first_registration_year', 'created_date', 'deleted_date',
#        'search_views', 'detail_views', 'stock_days2', 'ctr2', 'dv_perD',
#        'sv_perD', 'old', 'product_tier_n', 'make_name_n'],
#       dtype='object')

# %%
iksy3 = cut_data1.drop(['product_tier', 'make_name',
       'first_registration_year', 'created_date', 'deleted_date',
       'search_views', 'detail_views', 'ctr2', 'dv_perD',
       'sv_perD'], axis = 'columns')

# %%
iksy3
# Out:
#        price  first_zip_digit  stock_days2  old  product_tier_n  make_name_n
# 38868   6850                7         10.0   14               0           21
# 29915    850                5         42.0   15               0           23
# 45555  16950                7         74.0    6               0           19
# 77759   2995                6         13.0    9               0           28
# 72821   4300                4         90.0   11               0           31
# 3076    1850                4          7.0   16               0           22
# 48396   6450                1         16.0   10               0           31
# 51363   9450                3         10.0    3               0           31
# 71680   9250                3         22.0    3               0           31
# 13874  24890                4         90.0    5               0            2
# 6915   25250                6         57.0    4               0           32
# ...

# %%
X4 = iksy3
ys3 = cut_data1.search_views

# %%
X4_train, X4_test, ys3_train, ys3_test = train_test_split(X4, ys3, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X4_train = sc.fit_transform(X4_train)
X4_test = sc.transform(X4_test)
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
regressor = RandomForestRegressor(n_estimators=150, random_state=0)
regressor.fit(X3_train, ys2_train)
ys2_pred = regressor.predict(X3_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ys2_test, ys2_pred))
print('Mean Squared Error:', metrics.mean_squared_error(ys2_test, ys2_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ys2_test, ys2_pred)))
# Out:
# Mean Absolute Error: 1384.9514098480172
# Mean Squared Error: 15240229.626598768
# Root Mean Squared Error: 3903.873669395408

# %%
regressor.score(X3_test, ys2_test)
# Out:
# 0.49735326709920646

# %% [markdown]
# # Z search views w X-ach

# %%
iksy4 = cut_data1.drop(['product_tier', 'make_name',
       'first_registration_year', 'created_date', 'deleted_date',
    'detail_views', 'ctr2', 'dv_perD',
       'sv_perD'], axis = 'columns')

# %%
iksy4
# Out:
#        price  first_zip_digit  search_views  stock_days2  old  product_tier_n  \
# 38868   6850                7         297.0         10.0   14               0
# 29915    850                5        3920.0         42.0   15               0
# 45555  16950                7        1564.0         74.0    6               0
# 77759   2995                6        2372.0         13.0    9               0
# 72821   4300                4        3215.0         90.0   11               0
# 3076    1850                4         231.0          7.0   16               0
# 48396   6450                1         236.0         16.0   10               0
# 51363   9450                3          74.0         10.0    3               0
# 71680   9250                3         204.0         22.0    3               0
# 13874  24890                4        7456.0         90.0    5               0
# 6915   25250                6         635.0         57.0    4               0
# ...

# %%
X5 = iksy4
yd2 = cut_data1.detail_views

# %%
X5_train, X5_test, yd2_train, yd2_test = train_test_split(X5, yd2, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X5_train = sc.fit_transform(X5_train)
X5_test = sc.transform(X5_test)
# Out:
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bartek/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/bartek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
regressor = RandomForestRegressor(n_estimators=150, random_state=0)
regressor.fit(X5_train, yd2_train)
yd2_pred = regressor.predict(X5_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(yd2_test, yd2_pred))
print('Mean Squared Error:', metrics.mean_squared_error(yd2_test, yd2_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yd2_test, yd2_pred)))
# Out:
# Mean Absolute Error: 38.949774148053955
# Mean Squared Error: 11441.894630227202
# Root Mean Squared Error: 106.96679218443077

# %%
regressor.score(X5_test, yd2_test)
# Out:
# 0.7193019347104885
